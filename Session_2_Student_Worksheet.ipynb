# %% [markdown]
# <a href="https://colab.research.google.com/github/mperricone24/Week2_Pandas/blob/main/Session_2_Student_Worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Session 2 — Student Worksheet (Pandas + Plotly)
# Work in small groups. Find a CSV dataset on GitHub, load it in Colab, and adapt commands from the workbook.
# Be ready to walk through your code at the end.

# %% [markdown]
# ## Part 1 — Find a Dataset (GitHub)

# %%
csv_url = "https://raw.github.com/DJVolin/ClimateChangeNYC/blob/main/1950_through_2020.csv"
csv_url
# Out:
# 'https://raw.github.com/DJVolin/ClimateChangeNYC/blob/main/1950_through_2020.csv'

# %% [markdown]
# ## Part 2 — Load & Inspect

# %%
import pandas as pd

# Use the raw data URL from GitHub
csv_url = "https://raw.githubusercontent.com/DJVolin/ClimateChangeNYC/main/1950_through_2020.csv"
df = pd.read_csv(csv_url)
rows, cols = df.shape
rows, cols
# Out:
# (852, 8)

# %% [markdown]
# ## Part 3 — Explore & Clean

# %%
df.dtypes

df.isnull().sum().sort_values(ascending=False).head(10)

# %%
df.dtypes
# Out:
# Year           int64
# Month         object
# Avg. High    float64
# Avg. Low     float64
# Average      float64
# Hottest        int64
# Coldest        int64
# Precip.      float64
# dtype: object

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Year, Month, Avg. High, Avg. Low, Average, Hottest, Coldest, Precip.]
# Index: []

# %%
df
# Out:
#      Year Month  Avg. High  Avg. Low  Average  Hottest  Coldest  Precip.
# 0    1950   JAN       48.6      33.8     41.2       72       14     2.50
# 1    1950   FEB       38.3      26.4     32.4       50        6     4.20
# 2    1950   MAR       44.7      28.5     36.6       65       10     3.25
# 3    1950   APR       56.2      40.0     48.1       73       27     1.92
# 4    1950   MAY       66.5      50.3     58.4       82       41     2.47
# ..    ...   ...        ...       ...      ...      ...      ...      ...
# 847  2020   AUG       86.2      73.2     79.7       95       67     4.90
# 848  2020   SEP       77.3      64.8     71.1       89       51     4.17
# 849  2020   OCT       65.6      54.2     59.9       77       35     5.16
# 850  2020   NOV       61.4      47.2     54.3       78       33     4.42
# 851  2020   DEC       46.5      35.3     40.9       63       24     3.53
#
# [852 rows x 8 columns]

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# Year         0
# Month        0
# Avg. High    0
# Avg. Low     0
# Average      0
# Hottest      0
# Coldest      0
# Precip.      0
# dtype: int64

# %% [markdown]
# ## Part 4 — Summarization

# %%
category_col = 'Year'
numeric_col = 'Avg. High'

by_cat = df.groupby(category_col)[numeric_col].mean().sort_values(ascending=False)
by_cat.head(10)
# Out:
# Year
# 2016    65.716667
# 2020    65.291667
# 2006    65.191667
# 1991    65.191667
# 2012    65.041667
# 1990    64.641667
# 1953    64.591667
# 2010    64.466667
# 2017    64.408333
# 1998    64.258333
# Name: Avg. High, dtype: float64

# %%
category_col_2 = 'Year'
numeric_col_2 = 'Avg. Low'

by_cat_2 = df.groupby(category_col_2)[numeric_col_2].mean().sort_values(ascending=False)
by_cat_2.head(10)
# Out:
# Year
# 2012    51.908333
# 2020    51.850000
# 2006    51.683333
# 2016    51.558333
# 1998    51.391667
# 2010    51.133333
# 2017    51.025000
# 1991    50.575000
# 2018    50.358333
# 1990    50.250000
# Name: Avg. Low, dtype: float64

# %% [markdown]
# ## Part 5 — Visualization (Pandas + Plotly)

# %%
import plotly.express as px

#bar_df = by_cat.head(10).reset_index()
#fig = px.bar(bar_df, x=category_col, y=numeric_col, title=f'Top 10 {category_col} (interactive)')
#fig.show()

# %%
import plotly.express as px

scatter_df = df.groupby(category_col)[numeric_col].mean().reset_index()
fig = px.scatter(scatter_df, x=category_col, y=numeric_col, trendline='ols', title=f'{numeric_col} over time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02deff2e-e6d9-43df-af83-fddd28f538b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02deff2e-e6d9-43df-af83-fddd28f538b8")) {                    Plotly.newPlot(                        "02deff2e-e6d9-43df-af83-fddd28f538b8",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAvg. High=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[61.11666666666667,62.9,63.15833333333333,64.59166666666667,62.925000000000004,62.833333333333336,61.175000000000004,63.125,59.56666666666666,62.9,61.5,61.125,59.824999999999996,60.39166666666667,61.48333333333333,61.34166666666667,61.30833333333334,59.800000000000004,60.73333333333333,60.1,61.03333333333333,60.99166666666667,58.875,62.53333333333333,61.23333333333333,61.15833333333333,61.44166666666666,60.59166666666667,59.14166666666667,60.51666666666667,60.60833333333333,60.85,60.55833333333334,62.13333333333333,61.550000000000004,62.4,62.21666666666667,61.84166666666667,61.85833333333333,61.31666666666666,64.64166666666667,65.19166666666666,61.49166666666667,62.708333333333336,63.35,63.0,61.13333333333333,62.15833333333333,64.25833333333334,63.81666666666666,61.425000000000004,63.73333333333333,63.85,60.699999999999996,61.775,62.90833333333333,65.19166666666666,63.800000000000004,63.31666666666667,61.38333333333333,64.46666666666667,63.574999999999996,65.04166666666667,62.458333333333336,61.25,63.708333333333336,65.71666666666667,64.40833333333333,63.63333333333333,63.050000000000004,65.29166666666667],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eAvg. High = 0.0381156 * Year + -13.4457\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.242093\u003cbr\u003e\u003cbr\u003eYear=%{x}\u003cbr\u003eAvg. High=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[60.87980242566532,60.91791806393941,60.9560337022135,60.99414934048758,61.032264978761674,61.07038061703577,61.10849625530986,61.14661189358395,61.18472753185803,61.22284317013212,61.260958808406215,61.29907444668031,61.337190084954386,61.37530572322848,61.41342136150257,61.451536999776664,61.48965263805074,61.527768276324835,61.56588391459893,61.60399955287302,61.6421151911471,61.68023082942119,61.718346467695284,61.756462105969376,61.794577744243455,61.83269338251755,61.87080902079164,61.90892465906573,61.947040297339825,61.9851559356139,62.023271573887996,62.06138721216209,62.09950285043618,62.13761848871026,62.17573412698435,62.213849765258445,62.25196540353254,62.290081041806616,62.32819668008071,62.3663123183548,62.40442795662889,62.44254359490297,62.480659233177064,62.51877487145116,62.55689050972525,62.59500614799934,62.63312178627342,62.671237424547 ...

# %%
scatter_df_2 = df.groupby(category_col)[numeric_col_2].mean().reset_index()
fig = px.scatter(scatter_df_2, x=category_col, y=numeric_col_2, trendline='ols', title=f'{numeric_col_2} over time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ce9ccd68-7936-4687-9836-44cef86fffcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce9ccd68-7936-4687-9836-44cef86fffcb")) {                    Plotly.newPlot(                        "ce9ccd68-7936-4687-9836-44cef86fffcb",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAvg. Low=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[46.25833333333333,47.85833333333333,48.96666666666667,49.68333333333334,47.699999999999996,47.51666666666667,47.19166666666666,48.51666666666667,46.39166666666667,48.18333333333334,47.26666666666667,47.583333333333336,46.025000000000006,46.199999999999996,47.85833333333333,48.43333333333334,48.550000000000004,46.324999999999996,46.574999999999996,46.90833333333333,47.458333333333336,48.0,45.34166666666667,48.925000000000004,47.39166666666667,48.23333333333333,47.15833333333333,46.76666666666667,45.90833333333333,47.199999999999996,47.40833333333333,47.916666666666664,47.00833333333333,48.10833333333333,47.85,48.25,47.75,47.574999999999996,47.68333333333334,47.53333333333333,50.25,50.574999999999996,47.35,48.074999999999996,47.80833333333334,48.85833333333333,48.125,48.43333333333334,51.39166666666667,50.00833333333333,48.074999999999996,50.18333333333334,50.01666666666667,47.458333333333336,48.39166666666667,49.48333333333333,51.68333333333334,49.90833333333333,49.475,48.324999999999996,51.13333333333333,49.791666666666664,51.90833333333333,49.31666666666666,47.583333333333336,49.39166666666667,51.55833333333333,51.025,50.35833333333333,49.4,51.85],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eAvg. Low = 0.0478543 * Year + -46.5874\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.408150\u003cbr\u003e\u003cbr\u003eYear=%{x}\u003cbr\u003eAvg. Low=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[46.728618935837304,46.776473284149404,46.82432763246149,46.87218198077359,46.92003632908569,46.967890677397776,47.015745025709876,47.063599374021976,47.11145372233406,47.15930807064616,47.20716241895826,47.25501676727035,47.30287111558245,47.35072546389455,47.398579812206634,47.446434160518734,47.49428850883082,47.54214285714292,47.58999720545502,47.637851553767106,47.68570590207921,47.73356025039131,47.78141459870339,47.82926894701549,47.87712329532759,47.92497764363968,47.97283199195178,48.02068634026388,48.068540688575965,48.116395036888065,48.16424938520015,48.21210373351225,48.25995808182435,48.30781243013644,48.35566677844854,48.40352112676064,48.45137547507272,48.49922982338482,48.54708417169692,48.59493852000901,48.64279286832111,48.690647216633195,48.738501564945295,48.786355913257395,48.83421026156948,48.882 ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# Group data by year and calculate the mean for both Avg. High and Avg. Low
scatter_df_high = df.groupby(category_col)[numeric_col].mean().reset_index()
scatter_df_low = df.groupby(category_col)[numeric_col_2].mean().reset_index()

# Create subplots: 1 row, 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=(f'{numeric_col} over time', f'{numeric_col_2} over time'))

# Add the first scatter plot (Avg. High)
fig_high = px.scatter(scatter_df_high, x=category_col, y=numeric_col, trendline='ols')
for trace in fig_high.data:
    fig.add_trace(trace, row=1, col=1)

# Add the second scatter plot (Avg. Low)
fig_low = px.scatter(scatter_df_low, x=category_col, y=numeric_col_2, trendline='ols')
for trace in fig_low.data:
    fig.add_trace(trace, row=1, col=2)

# Update layout for better appearance
fig.update_layout(height=600, width=1000, title_text="Average High and Low Temperatures Over Time")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f1fab1f-d72b-424f-99b7-64f0b542463b" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f1fab1f-d72b-424f-99b7-64f0b542463b")) {                    Plotly.newPlot(                        "2f1fab1f-d72b-424f-99b7-64f0b542463b",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAvg. High=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":
"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":" ...

# %% [markdown]
# ## Part 6 — Reflection
# - What needed adjusting when you switched datasets?
# - What was easier/harder vs the workbook?
# - What context/limitations should a policymaker know?

# %% [markdown]
# Reflection:
#  -I need to switch the sum() function to mean() in order to get the year average temperatures, rather than the sum of all of the averages
#  -
#  - Do not have a reason for this change, so a policy to mitigate these increase through policy is not yet available

# %% [markdown]
# ## Part 7 — ⚡ Lightning Chart Demos — Teach-Out Instructions

# %% [markdown]
# ### What is a Lightning Demo?
# A **rapid-fire mini-presentation**: 2 minutes per group. Show **one chart** + **one insight**, not your whole notebook.
#
# ### Demo Format (2 minutes)
# 1. **Context (15 sec):** Dataset name + 1-sentence purpose.
# 2. **Chart + Insight (75–90 sec):** Show interactive Plotly chart; state one clear finding; name one wrangling step.
# 3. **Caveat or Next Step (15–30 sec):** One limitation OR next idea.
# 4. **Pass the mic (10 sec):** End with *“Any questions about our chart?”*
#
# ### Unique Angles
# - Aggregation choice (sum vs mean, raw vs normalized).
# - Data cleaning step (conversion, deduping).
# - Encoding (bar vs line vs scatter).
# - Interactivity (facet, hover, filter).
# - Comparability (per capita vs raw counts).
# - Temporal nuance (trend vs snapshot).
#
# 👉 If another group showed your angle, pick a different one.
#
# ### Flow for the Day
# - Groups present **clustered by chart type** (bars, lines, scatter, other).
# - Instructor summarizes similarities/differences after each cluster.
# - 15 groups × 2 min = ~30 minutes + transitions = ~40 minutes.
#
# ### Presenter Checklist
# - [ ] Dataset URL loads in Colab
# - [ ] Columns chosen make sense
# - [ ] One **interactive Plotly figure** with title + labels
# - [ ] Insight stated in one sentence
# - [ ] One cleaning step mentioned
#
# ### Audience Task
# After each cluster, jot 1 sentence:
# - What was **similar** across charts?
# - What was **different** (aggregation, encoding, interactivity)?
# - Which chart best supported a **policy decision**—and why?
#
# ---
# ### Quick Rubric (3 pts)
# - **Clarity of claim (1 pt)**
# - **Method fit (1 pt)**
# - **Insight/caveat (1 pt)**
# (Bonus +0.5 for meaningful interactivity)
#
# ---
# ### Minimal Code Patterns
#
# **Top-N bar:**
# ```python
# bar_df = df.groupby(category_col)[numeric_col].sum().nlargest(10).reset_index()
# fig = px.bar(bar_df, x=category_col, y=numeric_col,
#              title=f"Top 10 {category_col} by {numeric_col}")
# fig.show()
# ```
#
# **Time series:**
# ```python
# ts = (df.groupby(time_col)[numeric_col]
#         .sum()
#         .reset_index()
#         .sort_values(time_col))
# fig = px.line(ts, x=time_col, y=numeric_col, markers=True,
#               title=f"{numeric_col} over time")
# fig.show()
# ```
#
# **Scatter:**
# ```python
# fig = px.scatter(df, x=x_col, y=y_col, trendline="ols",
#                  title=f"{y_col} vs {x_col}")
# fig.show()
# ```
#
# ---
